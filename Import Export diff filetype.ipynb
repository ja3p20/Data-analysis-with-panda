# %%
import pandas as pd

# %%
URL = "https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv"
baby_names = pd.read_csv(URL)

# %%
baby_names.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 1           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 2           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Sophia
# 3           2016  FEMALE  ASIAN AND PACIFIC ISLANDER               Emma
# 4           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Emily
#
#    Count  Rank
# 0    172     1
# 1    112     2
# 2    104     3
# 3     99     4
# 4     99     4

# %%
baby_names["Child\'s First Name"].tolist()

baby_names["Child\'s First Name"].to_frame()
# Out:
#       Child's First Name
# 0                 Olivia
# 1                  Chloe
# 2                 Sophia
# 3                   Emma
# 4                  Emily
# 5                    Mia
# 6              Charlotte
# 7                  Sarah
# 8               Isabella
# 9                 Hannah
# 10                 Grace
# 11                Angela
# 12                   Ava
# 13                Joanna
# 14                Amelia
# 15                Evelyn
# 16                  Ella
# 17                  Arya
# 18                Ariana
# 19                  Maya
# 20                 Alina
# 21                 Fiona
# 22                Ashley
# 23                 Anaya
# 24                Fatima
# 25                  Anna
# 26                  Aria
# 27               Abigail
# 28              Victoria
# 29                  Abby
# ...                  ...
# 19388              BRYCE
# 19389             ASHTON
# 19390              YONAH
# 19391           MOHAMMED
# 19392            KENNETH
# ...

# %%
", ".join(str(name) for name in baby_names["Child\'s First Name"])

Output = None  #comment this line to see the output

# %%
baby_names.to_csv("NYC Baby Names.csv", index = False) #this is how you export csv
#watch out the name , if it already exist jupyter will no give an alert , it directly overwrites the file

# %%
baby_names.to_csv("NYC Baby Names.csv", index = False, columns = ["Year of Birth", "Child\'s First Name"], encoding="utf-8")

# %% [markdown]
# conda install xlrd
# conda install openpyxl

# %%
df = pd.read_excel("pandas/Data - Single Worksheet.xlsx")
df
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
pd.read_excel("pandas/Data - Multiple Worksheets.xlsx", sheet_name=1)
# Out:
#   First Name Last Name           City Gender
# 0     Parker     Power        Raleigh      F
# 1    Preston  Prescott   Philadelphia      F
# 2    Ronaldo   Donaldo         Bangor      M
# 3      Megan   Stiller  San Francisco      M
# 4     Bustin    Jieber         Austin      F

# %%
pd.read_excel("pandas/Data - Multiple Worksheets.xlsx", sheet_name=0)
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
data = pd.read_excel("pandas/Data - Multiple Worksheets.xlsx", sheet_name=["Data 1","Data 2"])

# %%
type(data)
# Out:
# collections.OrderedDict

# %%
data
# Out:
# OrderedDict([('Data 1',   First Name Last Name           City Gender
#               0    Brandon     James          Miami      M
#               1       Sean   Hawkins         Denver      M
#               2       Judy       Day    Los Angeles      F
#               3     Ashley      Ruiz  San Francisco      F
#               4  Stephanie     Gomez       Portland      F),
#              ('Data 2',   First Name Last Name           City Gender
#               0     Parker     Power        Raleigh      F
#               1    Preston  Prescott   Philadelphia      F
#               2    Ronaldo   Donaldo         Bangor      M
#               3      Megan   Stiller  San Francisco      M
#               4     Bustin    Jieber         Austin      F)])

# %%
data["Data 1"]
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
data["Data 2"]
# Out:
#   First Name Last Name           City Gender
# 0     Parker     Power        Raleigh      F
# 1    Preston  Prescott   Philadelphia      F
# 2    Ronaldo   Donaldo         Bangor      M
# 3      Megan   Stiller  San Francisco      M
# 4     Bustin    Jieber         Austin      F

# %%
data1 = pd.read_excel("pandas/Data - Multiple Worksheets.xlsx", sheet_name= None)  #automatically import all the worksheets

# %%
data1
# Out:
# OrderedDict([('Data 1',   First Name Last Name           City Gender
#               0    Brandon     James          Miami      M
#               1       Sean   Hawkins         Denver      M
#               2       Judy       Day    Los Angeles      F
#               3     Ashley      Ruiz  San Francisco      F
#               4  Stephanie     Gomez       Portland      F),
#              ('Data 2',   First Name Last Name           City Gender
#               0     Parker     Power        Raleigh      F
#               1    Preston  Prescott   Philadelphia      F
#               2    Ronaldo   Donaldo         Bangor      M
#               3      Megan   Stiller  San Francisco      M
#               4     Bustin    Jieber         Austin      F)])

# %%
baby_names.head(3)
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 1           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 2           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Sophia
#
#    Count  Rank
# 0    172     1
# 1    112     2
# 2    104     3

# %%
girls = baby_names[baby_names["Gender"]=="FEMALE"]
boys = baby_names[baby_names["Gender"]=="MALE"]

# %%
pd.ExcelWriter("Baby Names.xlsx") # to files are created, we just formed the foundation

# %%
excel_file =pd.ExcelWriter("Baby Names.xlsx")

# %%
girls.to_excel(excel_file, sheet_name= "Girls", index= False)
boys.to_excel(excel_file, sheet_name= "Boys", index= False, columns=["Gender","Child\'s First Name","Count"])

# %%
excel_file.save()  #this creates excel file
