# %%
import pandas as pd

# %%
df = pd.read_csv("pandas/employees.csv")
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df.info()  #see memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df["Start Date"].head(3)
# Out:
# 0     8/6/1993
# 1    3/31/1996
# 2    4/23/1993
# Name: Start Date, dtype: object

# %%
pd.to_datetime(df["Start Date"]).head(5)
# Out:
# 0   1993-08-06
# 1   1996-03-31
# 2   1993-04-23
# 3   2005-03-04
# 4   1998-01-24
# Name: Start Date, dtype: datetime64[ns]

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"]).head(3)

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
df["Gender"] = df["Gender"].astype("category")

# %%
df.info()  #see memeory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      3 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
df = pd.read_csv("pandas/employees.csv", parse_dates = ["Start Date", "Last Login Time"])
#df["Start Date"] = pd.to_datetime(df["Start Date"])
#df["Last Login Time"] = pd.to_datetime(df["Last Login Time"]).head(3)
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-06-18 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-06-18 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-06-18 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %% [markdown]
# Filter a dataframe based on a condition

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-06-18 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-06-18 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-06-18 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df["Gender"] == "Male" #remember to put double equal
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 970    False
# 971     True
# 972    False
# 973     True
# 974     True
# 975    False
# 976    False
# 977    False
# 978     True
# 979     True
# 980    False
# 981     True
# 982    False
# 983     True
# 984    False
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# 992     True
# 993    False
# 994     True
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df[df["Gender"] == "Male"].head(10) #show all the male values
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas   Male 1993-08-06 2019-06-18 12:42:00   97308    6.945
# 1      Thomas   Male 1996-03-31 2019-06-18 06:53:00   61933    4.170
# 3       Jerry   Male 2005-03-04 2019-06-18 13:00:00  138705    9.340
# 4       Larry   Male 1998-01-24 2019-06-18 16:47:00  101004    1.389
# 5      Dennis   Male 1987-04-18 2019-06-18 01:35:00  115163   10.125
# 12    Brandon   Male 1980-12-01 2019-06-18 01:08:00  112807   17.492
# 13       Gary   Male 2008-01-27 2019-06-18 23:40:00  109831    5.831
# 16     Jeremy   Male 2010-09-21 2019-06-18 05:56:00   90370    7.369
# 17      Shawn   Male 1986-12-07 2019-06-18 19:45:00  111737    6.414
# 21    Matthew   Male 1995-09-05 2019-06-18 02:12:00  100612   13.645
#
#     Senior Management             Team
# 0                True        Marketing
# 1                True              NaN
# 3                True          Finance
# 4                True  Client Services
# ...

# %%
df[df["Team"] == "Finance"]

#or

mask = df["Team"] == "Finance"
df[mask]

Output = None

# %%
df[df["Salary"] > 110000]

df[df["Bonus %"] <1.5]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24 2019-06-18 16:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05 2019-06-18 06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11 2019-06-18 07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14 2019-06-18 20:13:00  107391    1.260
# 175     Willie    Male 1998-02-17 2019-06-18 20:20:00  146651    1.451
# 189   Clarence    Male 1998-05-02 2019-06-18 03:16:00   85700    1.215
# 217    Douglas    Male 1999-09-03 2019-06-18 16:00:00   83341    1.015
# 273   Nicholas    Male 1994-04-12 2019-06-18 20:21:00   74669    1.113
# 279       Ruby  Female 2000-11-08 2019-06-18 19:35:00  105946    1.139
# 365     Gloria     NaN 1983-07-19 2019-06-18 01:57:00  140885    1.113
# 445      Chris    Male 2006-12-12 2019-06-18 01:57:00   71642    1.496
# 481        NaN  Female 2013-04-27 2019-06-18 06:40:00   93847    1.085
# ...

# %%
mask = df["Start Date"] <= "1985-01-01"
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2019-06-18 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2019-06-18 01:08:00  112807   17.492
# 18       Diana  Female 1981-10-23 2019-06-18 10:27:00  132940   19.082
# 28       Terry    Male 1981-11-27 2019-06-18 18:30:00  124008   13.464
# 37       Linda  Female 1981-10-19 2019-06-18 20:49:00   57427    9.557
# 43     Marilyn  Female 1980-12-07 2019-06-18 03:16:00   73524    5.207
# 45       Roger    Male 1980-04-17 2019-06-18 11:32:00   88010   13.886
# 49       Chris     NaN 1980-01-24 2019-06-18 12:13:00  113590    3.055
# 78       Robin  Female 1983-06-04 2019-06-18 15:15:00  114797    5.965
# 82      Steven    Male 1980-03-30 2019-06-18 21:20:00   35095    8.379
# 94       Harry    Male 1981-08-26 2019-06-18 15:16:00  130620    7.030
# 115     Pamela  Female 1982-07-01 2019-06-18 06:51:00   54585    4.166
# ...

# %%
mask1 = df["Gender"] == "Male"

# %%
mask2 = df["Team"] == "Marketing"

# %%
df[mask1 & mask2].head(6) # both condition have to be true
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2019-06-18 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2019-06-18 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2019-06-18 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2019-06-18 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2019-06-18 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2019-06-18 10:20:00   61602   11.849
#
#      Senior Management       Team
# 0                 True  Marketing
# 21               False  Marketing
# 26                True  Marketing
# 74               False  Marketing
# 77                True  Marketing
# 101               True  Marketing

# %%
mask3 = df["Senior Management"]

mask4 = df["Start Date"] < "1990-01-01"

df[mask3 | mask4].head() #either one or both
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2019-06-18 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2019-06-18 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2019-06-18 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2019-06-18 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2019-06-18 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
mask5 = df["First Name"] =="Robert"

mask6 = df["Team"] == "Client Services"

mask7 = df["Start Date"] > "2016-06-01"

df[(mask5 & mask6) | mask7]  #put parenthesis for specific evaluation
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2019-06-18 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2019-06-18 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2019-06-18 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2019-06-18 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-06-18 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-06-18 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-06-18 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
#mask11 = df["Team"] == "Legal"
#mask22 = df["Team"] == "Sales"
#mask33 = df["Team"] == "Product"  #repetitive code not good

#df[mask1 | mask2 | mask3]

#or
 
mask111 = df["Team"].isin(["Legal", "Sales", "Product"])  # you can add easily
df[mask111]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5         Dennis    Male 1987-04-18 2019-06-18 01:35:00  115163   10.125
# 6           Ruby  Female 1987-08-17 2019-06-18 16:20:00   65476   10.012
# 11         Julie  Female 1997-10-26 2019-06-18 15:19:00  102508   12.637
# 13          Gary    Male 2008-01-27 2019-06-18 23:40:00  109831    5.831
# 15       Lillian  Female 2016-06-05 2019-06-18 06:09:00   59414    1.256
# 17         Shawn    Male 1986-12-07 2019-06-18 19:45:00  111737    6.414
# 19         Donna  Female 2010-07-22 2019-06-18 03:48:00   81014    1.894
# 20          Lois     NaN 1995-04-22 2019-06-18 19:18:00   64714    4.934
# 27         Scott     NaN 1991-07-11 2019-06-18 18:58:00  122367    5.218
# 29      Benjamin    Male 2005-01-26 2019-06-18 22:06:00   79529    7.008
# 31         Joyce     NaN 2005-02-20 2019-06-18 14:40:00   88657   12.752
# 35       Theresa  Female 2006-10-10 2019-06-18 01:12:00   85182   16.675
# ...

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-06-18 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-06-18 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-06-18 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
a = df["Team"].isnull() # you cannot do df["Team"] == "NaN"
df[a]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2019-06-18 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2019-06-18 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2019-06-18 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2019-06-18 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2019-06-18 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2019-06-18 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2019-06-18 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2019-06-18 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2019-06-18 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2019-06-18 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2019-06-18 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2019-06-18 06:06:00   66067   10.957
# ...

# %%
b = df["Gender"].notnull()
df[b]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2019-06-18 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2019-06-18 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2019-06-18 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2019-06-18 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2019-06-18 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2019-06-18 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2019-06-18 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2019-06-18 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2019-06-18 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2019-06-18 06:51:00  139852    7.524
# 10      Louise  Female 1980-08-12 2019-06-18 09:01:00   63241   15.132
# 11       Julie  Female 1997-10-26 2019-06-18 15:19:00  102508   12.637
# ...

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-06-18 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-06-18 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-06-18 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df[df["Salary"].between(60000,70000)].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2019-06-18 06:53:00   61933    4.170
# 6        Ruby  Female 1987-08-17 2019-06-18 16:20:00   65476   10.012
# 10     Louise  Female 1980-08-12 2019-06-18 09:01:00   63241   15.132
# 20       Lois     NaN 1995-04-22 2019-06-18 19:18:00   64714    4.934
# 41  Christine     NaN 2015-06-28 2019-06-18 01:08:00   66582   11.308
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# 10               True                   NaN
# 20               True                 Legal
# 41               True  Business Development

# %%
df[df["Last Login Time"].between("08:30AM","12:00PM")].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2019-06-18 11:17:00  130590   11.858
# 7         NaN  Female 2015-07-20 2019-06-18 10:43:00   45906   11.598
# 10     Louise  Female 1980-08-12 2019-06-18 09:01:00   63241   15.132
# 18      Diana  Female 1981-10-23 2019-06-18 10:27:00  132940   19.082
# 33       Jean  Female 1993-12-18 2019-06-18 09:07:00  119082   16.180
#
#     Senior Management                  Team
# 2               False               Finance
# 7                True               Finance
# 10               True                   NaN
# 18              False       Client Services
# 33              False  Business Development

# %%
df.sort_values("First Name", inplace=True)

# %%
aa = ~df["First Name"].duplicated(keep = False)
df[aa] # show unique values
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2019-06-18 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2019-06-18 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2019-06-18 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2019-06-18 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2019-06-18 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2019-06-18 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2019-06-18 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2019-06-18 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2019-06-18 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %%
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2019-06-18 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2019-06-18 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2019-06-18 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
df.drop_duplicates("First Name",keep="first") #keep the first occurence value
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2019-06-18 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2019-06-18 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2019-06-18 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2019-06-18 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2019-06-18 09:34:00   47638   11.209
# 639     Amanda     NaN 1991-08-11 2019-06-18 14:15:00   46665   19.391
# 879        Amy  Female 2009-05-20 2019-06-18 06:26:00   75415   19.132
# 430     Andrea  Female 2010-10-01 2019-06-18 11:54:00   79123   19.422
# 564     Andrew    Male 1985-03-29 2019-06-18 18:57:00   43414    7.563
# 8       Angela  Female 2005-11-22 2019-06-18 06:29:00   95570   18.523
# 509        Ann  Female 1984-11-04 2019-06-18 12:17:00   90719    6.220
# 645       Anna     NaN 1985-03-13 2019-06-18 09:19:00   45418   10.162
# ...

# %%
df.drop_duplicates(subset= ["Team"], keep= False)
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
df.drop_duplicates(subset= ["First Name","Team"])
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2019-06-18 10:20:00   61602   11.849
# 440      Aaron    Male 1990-07-22 2019-06-18 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2019-06-18 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2019-06-18 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2019-06-18 11:59:00   71276    5.027
# 300       Alan    Male 1988-06-26 2019-06-18 03:54:00  111786    3.592
# 53        Alan     NaN 2014-03-03 2019-06-18 13:28:00   40341   17.578
# 610       Alan    Male 2012-02-17 2019-06-18 00:26:00   41453   10.084
# 372     Albert    Male 1997-02-01 2019-06-18 16:20:00   67827   19.717
# 458     Albert    Male 2007-09-30 2019-06-18 17:34:00  102626   15.843
# 477     Albert    Male 2008-08-14 2019-06-18 17:43:00  137840    9.705
# 999     Albert    Male 2012-05-15 2019-06-18 18:24:00  129949   10.169
# ...

# %%
df = pd.read_csv("pandas/employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-06-18 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-06-18 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-06-18 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df["Gender"].unique()

df["Team"].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
len(df["Team"].unique())
# Out:
# 11

# %%
df["Team"].nunique()  #does not include null thats why ans is 10
# Out:
# 10

# %%
df["Team"].nunique(dropna=False)
# Out:
# 11
