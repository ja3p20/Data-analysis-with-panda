# %%
import pandas as pd

# %%
chicago = pd.read_csv("pandas/chicago.csv")
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null object
# Employee Annual Salary    32062 non-null object
# dtypes: object(4)
# memory usage: 1002.0+ KB

# %%
chicago["Department"].nunique()
# Out:
# 35

# %%
chicago["Department"].count()
# Out:
# 32062

# %%
chicago["Department"] = chicago["Department"].astype("category")

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null category
# Employee Annual Salary    32062 non-null object
# dtypes: category(1), object(3)
# memory usage: 784.4+ KB

# %%
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago["Name"].str.lower().str.upper().head(3)
# Out:
# 0      AARON,  ELVIA J
# 1    AARON,  JEFFERY M
# 2       AARON,  KARINA
# Name: Name, dtype: object

# %%
chicago["Name"].str.title().head(3)
# Out:
# 0      Aaron,  Elvia J
# 1    Aaron,  Jeffery M
# 2       Aaron,  Karina
# Name: Name, dtype: object

# %%
chicago["Position Title"] = chicago["Position Title"].str.title()

# %%
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  Water Rate Taker  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    Police Officer       POLICE              $84450.00
# 2     AARON,  KARINA    Police Officer       POLICE              $84450.00

# %%
chicago["Department"].str.len().head(3)
# Out:
# 0    11.0
# 1     6.0
# 2     6.0
# Name: Department, dtype: float64

# %%
chicago = pd.read_csv("pandas/chicago.csv").dropna(how = "all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
chicago["Department"] = chicago["Department"].str.replace("MGMNT", "MANAGEMENT")

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER  WATER MANAGEMENT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV  WATER MANAGEMENT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago["Employee Annual Salary"] = chicago["Employee Annual Salary"].str.replace("$","").astype(float)

# %%
chicago["Employee Annual Salary"].nlargest(10)
# Out:
# 8184     300000.0
# 7954     216210.0
# 25532    202728.0
# 8924     197736.0
# 8042     197724.0
# 19208    195000.0
# 3706     187680.0
# 18556    187680.0
# 29466    187680.0
# 13754    185364.0
# Name: Employee Annual Salary, dtype: float64

# %%
chicago.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#        Employee Annual Salary
# 32059                 84450.0
# 32060                 87384.0
# 32061                113664.0

# %%
mask = chicago["Position Title"].str.lower().str.contains("water")
chicago[mask]
# Out:
#                           Name                                 Position Title  \
# 0              AARON,  ELVIA J                               WATER RATE TAKER
# 554         ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671            ANDER,  PERRY A                               WATER CHEMIST II
# 685        ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702          ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
# 1054          ASHLEY,  KARMA T                               WATER CHEMIST II
# 1079         ATKINS,  JOANNA M                               WATER CHEMIST II
# 1181        AZEEM,  MOHAMMED A                               WATER CHEMIST II
# 1285            BAJIC,  JOHN A                          WATER METER MACHINIST
# 2400          BOLTON,  BRIAN E                               WATER RATE TAKER
# 2586           BOYCE,  ADNER L                               WATER CHEMIST II
# ...

# %%
chicago[chicago["Position Title"].str.lower().str.startswith("water")]
# Out:
#                           Name               Position Title        Department  \
# 0              AARON,  ELVIA J             WATER RATE TAKER  WATER MANAGEMENT
# 671            ANDER,  PERRY A             WATER CHEMIST II  WATER MANAGEMENT
# 1054          ASHLEY,  KARMA T             WATER CHEMIST II  WATER MANAGEMENT
# 1079         ATKINS,  JOANNA M             WATER CHEMIST II  WATER MANAGEMENT
# 1181        AZEEM,  MOHAMMED A             WATER CHEMIST II  WATER MANAGEMENT
# 1285            BAJIC,  JOHN A        WATER METER MACHINIST  WATER MANAGEMENT
# 2400          BOLTON,  BRIAN E             WATER RATE TAKER  WATER MANAGEMENT
# 2586           BOYCE,  ADNER L             WATER CHEMIST II  WATER MANAGEMENT
# 2745          BRANDYS,  DANIEL             WATER CHEMIST II  WATER MANAGEMENT
# 3143          BROWN,  SHARON L             WATER RATE TAKER  WATER MANAGEMENT
# 3246      BUCHANAN,  ANTHONY L             WATER CHEMIST II  WATER MANAGEMENT
# ...

# %%
chicago[chicago["Position Title"].str.lower().str.endswith("ist")].head()
# Out:
#                     Name                        Position Title  \
# 184       AFROZ,  NAYYAR                          PSYCHIATRIST
# 308     ALARCON,  LUIS J            LOAN PROCESSING SPECIALIST
# 422     ALLAIN,  CAROLYN  SENIOR TELECOMMUNICATIONS SPECIALIST
# 472       ALLEN,  ROBERT                             MACHINIST
# 705  ANDERSON,  EDWARD M             SR PROCUREMENT SPECIALIST
#
#                 Department  Employee Annual Salary
# 184                 HEALTH                 99840.0
# 308  COMMUNITY DEVELOPMENT                 81948.0
# 422                   DoIT                 89880.0
# 472       WATER MANAGEMENT                 94328.0
# 705            PROCUREMENT                 91476.0

# %%
chicago["Name"] = chicago["Name"].str.rstrip().str.lstrip()

# %%
chicago["Position Title"] = chicago["Position Title"].str.strip()

# %%
chicago = pd.read_csv("pandas/chicago.csv", index_col = "Name").dropna(how = "all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.tail(3)
# Out:
#                               Position Title Department Employee Annual Salary
# Name
# ZYMANTAS,  MARK E             POLICE OFFICER     POLICE              $84450.00
# ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE              $87384.00
# ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT             $113664.00

# %%
chicago.index
# Out:
# Index(['AARON,  ELVIA J', 'AARON,  JEFFERY M', 'AARON,  KARINA',
#        'AARON,  KIMBERLEI R', 'ABAD JR,  VICENTE M', 'ABARCA,  ANABEL',
#        'ABARCA,  EMMANUEL', 'ABASCAL,  REECE E', 'ABBASI,  CHRISTOPHER',
#        'ABBATACOLA,  ROBERT J',
#        ...
#        'ZWIT,  JEFFREY J', 'ZWOLFER,  MATTHEW W', 'ZYCH,  MATEUSZ',
#        'ZYDEK,  BRYAN', 'ZYGADLO,  JOHN P', 'ZYGADLO,  MICHAEL J',
#        'ZYGOWICZ,  PETER J', 'ZYMANTAS,  MARK E', 'ZYRKOWSKI,  CARLO E',
#        'ZYSKOWSKI,  DARIUSZ'],
#       dtype='object', name='Name', length=32062)

# %%
chicago.index = chicago.index.str.strip().str.title()

# %%
chicago.index
# Out:
# Index(['Aaron,  Elvia J', 'Aaron,  Jeffery M', 'Aaron,  Karina',
#        'Aaron,  Kimberlei R', 'Abad Jr,  Vicente M', 'Abarca,  Anabel',
#        'Abarca,  Emmanuel', 'Abascal,  Reece E', 'Abbasi,  Christopher',
#        'Abbatacola,  Robert J',
#        ...
#        'Zwit,  Jeffrey J', 'Zwolfer,  Matthew W', 'Zych,  Mateusz',
#        'Zydek,  Bryan', 'Zygadlo,  John P', 'Zygadlo,  Michael J',
#        'Zygowicz,  Peter J', 'Zymantas,  Mark E', 'Zyrkowski,  Carlo E',
#        'Zyskowski,  Dariusz'],
#       dtype='object', name='Name', length=32062)

# %%
chicago.head(3)
# Out:
#                      Position Title   Department Employee Annual Salary
# Name
# Aaron,  Elvia J    WATER RATE TAKER  WATER MGMNT              $90744.00
# Aaron,  Jeffery M    POLICE OFFICER       POLICE              $84450.00
# Aaron,  Karina       POLICE OFFICER       POLICE              $84450.00

# %%
chicago.columns = chicago.columns.str.upper()

# %%
chicago.head(3)
# Out:
#                      POSITION TITLE   DEPARTMENT EMPLOYEE ANNUAL SALARY
# Name
# Aaron,  Elvia J    WATER RATE TAKER  WATER MGMNT              $90744.00
# Aaron,  Jeffery M    POLICE OFFICER       POLICE              $84450.00
# Aaron,  Karina       POLICE OFFICER       POLICE              $84450.00

# %%
chicago = pd.read_csv("pandas/chicago.csv").dropna(how = "all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
chicago["Name"].str.split(",").str.get(0).str.title().value_counts()
# Out:
# Williams         293
# Johnson          244
# Smith            241
# Brown            185
# Jones            183
# Rodriguez        171
# Jackson          136
# Garcia           130
# Davis            127
# Hernandez        110
# Martinez         108
# Lopez            106
# Gonzalez         104
# Perez            100
# Wilson            94
# Rivera            90
# Thomas            89
# Anderson          82
# Torres            81
# Murphy            80
# Robinson          79
# Moore             78
# Harris            76
# Sanchez           76
# Miller            75
# Lewis             74
# Taylor            73
# Martin            72
# Clark             66
# White             66
#                 ...
# Culloton           1
# Devaney            1
# Fobbs              1
# Vosburgh           1
# Tocco              1
# Dameron            1
# Robinson Bass      1
# Jemison            1
# Villanova          1
# Gameng             1
# Kero               1
# Pasiewicz          1
# ...

# %%
chicago["Position Title"].str.split(" ").str.get(0).value_counts()
# Out:
# POLICE                   10856
# FIREFIGHTER-EMT           1509
# SERGEANT                  1186
# POOL                       918
# FIREFIGHTER                810
# CROSSING                   775
# MOTOR                      721
# SANITATION                 715
# PARAMEDIC                  641
# ASST                       606
# FIRE                       512
# TRAFFIC                    512
# SENIOR                     470
# CONSTRUCTION               452
# LIEUTENANT-EMT             394
# ADMINISTRATIVE             375
# LIBRARY                    365
# LIBRARIAN                  335
# LIEUTENANT                 332
# OPERATING                  324
# ELECTRICAL                 313
# AVIATION                   309
# FIREFIGHTER/PARAMEDIC      259
# GENERAL                    257
# STAFF                      250
# CLERK                      242
# FOREMAN                    237
# HOISTING                   214
# DEPUTY                     213
# LABORER                    210
# ...

# %%
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago["Name"].str.split(",").str.get(1).str.split(" ").head(3)
# Out:
# 0      [, , ELVIA, J]
# 1    [, , JEFFERY, M]
# 2        [, , KARINA]
# Name: Name, dtype: object

# %%
chicago["Name"].str.split(",").str.get(1).str.strip().str.split(" ").str.get(0).value_counts().head()
# Out:
# MICHAEL    1153
# JOHN        899
# JAMES       676
# ROBERT      622
# JOSEPH      537
# Name: Name, dtype: int64

# %%
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago[["First Name", "Last Name"]] = chicago["Name"].str.split(",", expand = True)

# %%
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary  \
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00
#
#   First Name    Last Name
# 0      AARON      ELVIA J
# 1      AARON    JEFFERY M
# 2      AARON       KARINA

# %%
chicago["Position Title"].str.split(" ", expand = True).head(4)
# Out:
#         0         1          2     3     4     5     6     7     8
# 0   WATER      RATE      TAKER  None  None  None  None  None  None
# 1  POLICE   OFFICER       None  None  None  None  None  None  None
# 2  POLICE   OFFICER       None  None  None  None  None  None  None
# 3   CHIEF  CONTRACT  EXPEDITER  None  None  None  None  None  None

# %%
chicago["Position Title"].str.split(" ", expand = True, n=1).head(4)
# Out:
#         0                   1
# 0   WATER          RATE TAKER
# 1  POLICE             OFFICER
# 2  POLICE             OFFICER
# 3   CHIEF  CONTRACT EXPEDITER

# %%
chicago[["First Title Word", "Reamining Words"]] = chicago["Position Title"].str.split(" ", expand = True, n=1)

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary First Name      Last Name First Title Word  \
# 0              $90744.00      AARON        ELVIA J            WATER
# 1              $84450.00      AARON      JEFFERY M           POLICE
# 2              $84450.00      AARON         KARINA           POLICE
# 3              $89880.00      AARON    KIMBERLEI R            CHIEF
# 4             $106836.00    ABAD JR      VICENTE M            CIVIL
#
#       Reamining Words
# 0          RATE TAKER
# 1             OFFICER
# 2             OFFICER
# 3  CONTRACT EXPEDITER
# 4         ENGINEER IV
